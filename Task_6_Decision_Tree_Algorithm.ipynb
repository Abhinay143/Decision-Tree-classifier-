# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinay143/Decision-Tree-classifier-/blob/main/Task_6_Decision_Tree_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task-6:Prediction Using the Decision Tree Algorithm

# %% [markdown]
# **Name:Abhinay.Aitha**

# %% [markdown]
# Objective:To built the Decision Tree Classifier and visualize it

# %% [markdown]
# Importing Reqired libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##Reading the Dataset
df=pd.read_csv("/content/Iris (1).csv",index_col=None)
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
##last 10 rows
df.tail(10)
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 140  141            6.7  ...           2.4  Iris-virginica
# 141  142            6.9  ...           2.3  Iris-virginica
# 142  143            5.8  ...           1.9  Iris-virginica
# 143  144            6.8  ...           2.3  Iris-virginica
# 144  145            6.7  ...           2.5  Iris-virginica
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [10 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
##no of rows and columns
df.shape
# Out:
# (150, 6)

# %%
##Checking the null values
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Statistical Description

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Correlation

# %%
cor=df.corr()
sns.heatmap(cor,annot=True)

# %%
df["Species"]=df["Species"].astype("category").cat.codes

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# Preparing The data

# %%
x=df.iloc[:,1:5]
y=df.iloc[:,5]

# %% [markdown]
# Splitting The data into Train and Test

# %%
from sklearn.tree import DecisionTreeClassifier,export_graphviz
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
dtm=DecisionTreeClassifier(criterion="entropy",random_state=100)
dtm.fit(x_train,y_train)
predictions=dtm.predict(x_test)

# %% [markdown]
# Importing Required Libraries

# %%
from sklearn import tree
# !apt-get install python_pydot
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package python_pydot

# %%
# !pip install pydotplus

# %% [markdown]
# Visualizing the Decision Tree:

# %%
from IPython.display import Image
import pydotplus
from sklearn.externals.six import StringIO
dot_data=StringIO()
export_graphviz(dtm,out_file=dot_data,filled=True,rounded=True,special_characters=True)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
x.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %% [markdown]
# **Score**

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predictions)*100
# Out:
# 100.0

# %% [markdown]
# Conclusion:Decision Tree Classifier has been built such that it can predict the class accordingly.
